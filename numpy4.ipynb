# %% [markdown]
# <a href="https://colab.research.google.com/github/SuryARavichan/numpy_bas_ope/blob/main/numpy4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t_arr = np.linspace(-np.pi, np.pi, 200)
plt.plot(t_arr,np.tan(t_arr))

# %%
t_arr = np.linspace(-np.pi, np.pi, 200)
plt.plot(t_arr,np.sin(t_arr))

# %%
t_arr = np.linspace(-np.pi, np.pi, 200)
plt.plot(t_arr,np.cos(t_arr))

# %%
np.arcsin(1)
# Out:
# 1.5707963267948966

# %%
np.rad2deg(np.pi)
# Out:
# 180.0

# %%
np.deg2rad(np.pi)
# Out:
# 0.05483113556160755

# %%
np.hypot(10,10)
# Out:
# 14.142135623730951

# %%
from numpy import linalg as LA

# %%
arr_5 = [8,9,5,2,3]
arr_6 = [1,2,6,3,4]
arr_7 = [15,89,23,10,100]
np.dot(arr_5,arr_6)
# Out:
# 74

# %%
np.inner(arr_5,arr_7)
# Out:
# 1356
